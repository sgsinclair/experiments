# %% [markdown]
# # Skimming LCSH data from Gale files
#
# The goal of this notebook is to figure out a quick way to skim the thousands of ECCO and NCCO file metadata from Gale-Cengage, discover if they have a relevant Library of Congress Subject Heading, and, if the file does have a relevant LCSH, add it to a list.
#
# The terms I am looking for include `'travel', 'discov', 'explor', 'voyage', 'guide', 'antiquit'`. These are the same terms that I used to search the HTRC.
#
# In a past notebook, I struggled with using xml, in part because it was very slow to open an xml file, read the whole thing in to BeautifulSoup, and then see if what I wanted was there. This [lxml method from IBM](https://www.ibm.com/developerworks/xml/library/x-hiperfparse/), however, was helpful in developing something quicker.

# %%
from lxml
import pandas as pd
import glob
import lxml

# %%
# %%time 

context = etree.iterparse('files/sampleECCOtxt.xml', events=('end',), tag='locSubject')

loclist = []
for event, elem in context:
    loclist.append(elem.text)
# Let's just try printing these in a few different ways
# Out:
# Wall time: 866 ms

# %%
string = '; '.join(loclist)
string
# Out:
# 'Westminster (London, England); History; Early works to 1800; London (England); History; Early works to 1800'

# %%
for event, elem in context:
    print(elem.text)
    # Um, unsure why this isn't working, when it works above?

# %%
loclist
# Out:
# ['Westminster (London, England)',
#  'History',
#  'Early works to 1800',
#  'London (England)',
#  'History',
#  'Early works to 1800']

# %% [markdown]
# I should also not have to worry if the tag does not exist; as can be seen below, it won't break or throw an derror - the result will just be empy. So, I should still be able to apply my general method of something like `if word is in termlist`.

# %%
contextnone = etree.iterparse('files/sampleECCOtxt.xml', events=('end',), tag='holdings2')

# %%
emptylist = []
for event, elem in contextnone:
    emptylist.append(elem.text)
emptylist
# Out:
# []

# %% [markdown]
# ### Running over multiple files
#
# Let's try run this over a few files to see what happens. The main chunk of code below was originally running BeautifulSoup, which took way too long; hopefully this will move a bit more quickly!
#
# I will also need a list of metadata tags to iterate through, in order to grab the metadata for the files that I want. Let's do that first.
#
# I also have to remember that although this chunk of code should work for ECCO files, I may have to adjust it slightly to work with NCCO files, especially since lxml tags are sensitive to capital letters (or at least, they are they are used above).

# %%
taglist = ['documentID', 'ESTCID', 'pubDate','ESTCID',
           'language','module','locSubject','notes',
           'fullTitle','displayTitle','currentVolume', 
           'totalVolumes', 'imprintPublisher','imprintFull',
           'imprintCity', 'publicationPlace']

# %%
# set up a dict to hold all the strings of all these elements
elementdict = {}

for xmltag in taglist:
    elementlist = []
    context = etree.iterparse('files/sampleECCOtxt.xml', events=('end',), tag=xmltag)
    for event, elem in context:
        elementlist.append(elem.text)
    elementdict[xmltag] = ', '.join(elementlist)

# %%
#aaaand, let's see if it worked
elementdict
# Out:
# {'ESTCID': 'T228085',
#  'currentVolume': 'Volume 2',
#  'displayTitle': 'A new and compleat survey of London. In ten parts. I. All the publick transactions and memorable events, that have happened to the citizens, from ...',
#  'documentID': '1299400102',
#  'fullTitle': 'A new and compleat survey of London. In ten parts. I. All the publick transactions and memorable events, that have happened to the citizens, from its foundation, to the year 1742. II. A particular description of the thirteen wards on the East of Walbrook. III. Of the twelve wards on the West of Walbrook. IV. A political account of London; parallels between this and the most celebrated cities of antiquity, as well as the modern great cities of Europe, Asia and Africa. V. An historical account of the city governments, ecclesiastical, civil and military. VI. A full account of the great and extensive commerce of the city; and of the several incorporations of the arts and mysteries of the citizens. VII. Of the present state of learning in this city. VIII. History and antiquities of Westminster; its government, ecclesiastical and civil. IX. Of the several parishes and liberties in the county of Middlesex, within the bill of mortality. X. Of the borough of Southwark, and places contiguous in the county of Surry. In two volumes. By a citizen, and native of London.',
#  'imprintCity': 'London',
#  'imprintFull': 'London : printed for S. Lyne, at the Globe in Newgate-street; and J. Ilive, in Aldersgate-street, MDCCXLII. [1742]',
#  'imprintPublisher': 'printed for S. Lyne, at the Globe in Newgate-street; and J. Ilive, in Aldersgate-street',
#  'language': 'English',
#  'locSubject': 'Westminster (London, England), History, Early works to 1800, London (England), History, Early works to 1800',
#  'module': 'History and Geography',
#  'notes': 'In fact in two volumes; volume 2 has a separate register, but continuous pagination and the imprint reads: "London: printed for S. Lyne; and J. Ilive, 1742".  With an index.',
#  'pubDate': '17420101',
#  'publicationPlace': 'London',
#  'totalVolumes': '2'}

# %% [markdown]
# Great! And if we set up a file list and try to do two files, one with travel, one without, let's see if we can get that working...

# %%
twofiles = ['files/sampleECCOtextTravel.xml', 'files/sampleECCOtxt.xml']

# %%
# first, we only want the files that have certain LCSH
# so let's set up a list of tags
termlist = ['travel', 'discov', 'explor', 'voyage', 'guide', 'antiquit']

teststring = 'Italy, Description and travel, Early works to 1800'

# %%
# just to make sure that my if statement will work:
if any(x in teststring for x in termlist):
    print('yes')
else:
    print('no')
# Out:
# yes

# %% [markdown]
# ## _note_ Run the next cell before the below ones
# Make sure to establish the `taglist` and `termlist`

# %%
import pandas as pd
import glob
import lxml

taglist = ['documentID', 'ESTCID', 'pubDate','ESTCID',
           'language','module','locSubject','notes',
           'fullTitle','displayTitle','currentVolume', 
           'totalVolumes', 'imprintPublisher','imprintFull',
           'imprintCity', 'publicationPlace']
termlist = ['travel', 'discov', 'explor', 'voyage', 'guide', 'antiquit']

# %% [markdown]
# The next three cells have variations of:
# 1. two files, one with travel and one without: `8.82 s ± 2.84 s per loop (mean ± std. dev. of 10 runs, 1 loop each)`
# 2. one file, with travel: `7.18 s ± 751 ms per loop (mean ± std. dev. of 10 runs, 1 loop each)`
# 3. one file, without travel: `2.78 s ± 334 ms per loop (mean ± std. dev. of 10 runs, 1 loop each)`
#
# So, in general, if I have 3000 files and 300 of them are travel related (as was roughly the case below), it would take 9,720 s (162 minutes / 2.7 hours).
#
# Is there a way to do this more quickly? At this rate, since there is about 200,000 files on ECCO I and ECCO II, it will take 680,000 seconds, or 180 hours. Ouch.
#
# Of course, some of these sections - like medicine or Lit&Lang, will be much lower in the number of travel texts that they have, so that number of hours could drop by a lot. For example, if only 2% (rather than 10%) of all 200,000 files have a travel tag, the time then becomes 576,800 or 160ish hours.
#
# These files are on my local hard drive, and not on the Gale hard drive, so I am guessing these loops might go a bit faster than when I'm using the Gale hard drive? Google did not provide an easy answer to this.

# %%
# %%timeit -r 10

# this list of dicts will hold all a dict that holds
# the metadata for each relevant file
listofdicts = []

twofiles = ['files/sampleECCOtextTravel.xml', 'files/sampleECCOtxt.xml']

for file in twofiles:
    testparse = etree.iterparse(file, events=('end',), tag = 'locSubject')
    testlist = []
    for event, elem in testparse:
        testlist.append(elem.text)
    # reclaim the memory at the end of each loop -
    # clears unneeded node references
    elem.clear()
    while elem.getprevious() is not None:
        del elem.getparent()[0]
        
    teststring = ', '.join(testlist) 
    # print(teststring)
        
    if any(lcsh in teststring for lcsh in termlist):
        # print('yes')
        
        # if that is true, we want the metadata
        # so let's make a dict to hold it
        # this dict will be reset with every file loop
        filedict = {}
        
        for xmltag in taglist:
            # make an empty list to hold what is in each tag, 
            # which will be written to our dict in a few steps
            elementlist = []
            
            context = etree.iterparse(file, events=('end',), tag=xmltag)
            for event, elem in context:
                elementlist.append(elem.text)
            
            # the below should make things faster - I think? 
            # reclaim the memory at the end of each loop -
            # clears unneeded node references
            elem.clear()
            while elem.getprevious() is not None:
                del elem.getparent()[0]
            # assign to the dictionary
            filedict[xmltag] = ', '.join(elementlist)
            
        # after it has looped through all the xmltags, 
        # add the filedict to list of dicts 
        listofdicts.append(filedict)
    #else:
        # print('no')
# Out:
# 8.82 s ± 2.84 s per loop (mean ± std. dev. of 10 runs, 1 loop each)

# %%
# %%timeit -r 10

# this list of dicts will hold all a dict that holds
# the metadata for each relevant file
listofdicts = []

travellist = ['files/sampleECCOtextTravel.xml']

for file in travellist:
    testparse = etree.iterparse(file, events=('end',), tag = 'locSubject')
    testlist = []
    for event, elem in testparse:
        testlist.append(elem.text)
    # reclaim the memory at the end of each loop -
    # clears unneeded node references
    elem.clear()
    while elem.getprevious() is not None:
        del elem.getparent()[0]
        
    teststring = ', '.join(testlist) 
    # print(teststring)
        
    if any(lcsh in teststring for lcsh in termlist):
        # print('yes')
        
        # if that is true, we want the metadata
        # so let's make a dict to hold it
        # this dict will be reset with every file loop
        filedict = {}
        
        for xmltag in taglist:
            # make an empty list to hold what is in each tag, 
            # which will be written to our dict in a few steps
            elementlist = []
            
            context = etree.iterparse(file, events=('end',), tag=xmltag)
            for event, elem in context:
                elementlist.append(elem.text)
            
            # the below should make things faster - I think? 
            # reclaim the memory at the end of each loop -
            # clears unneeded node references
            elem.clear()
            while elem.getprevious() is not None:
                del elem.getparent()[0]
            # assign to the dictionary
            filedict[xmltag] = ', '.join(elementlist)
            
        # after it has looped through all the xmltags, 
        # add the filedict to list of dicts 
        listofdicts.append(filedict)
    #else:
       # print('no')
# Out:
# 7.18 s ± 751 ms per loop (mean ± std. dev. of 10 runs, 1 loop each)

# %%
# %%timeit -r 10

# this list of dicts will hold all a dict that holds
# the metadata for each relevant file
listofdicts = []

nontravellist = ['files/sampleECCOtxt.xml']

for file in nontravellist:
    testparse = etree.iterparse(file, events=('end',), tag = 'locSubject')
    testlist = []
    for event, elem in testparse:
        testlist.append(elem.text)
    # reclaim the memory at the end of each loop -
    # clears unneeded node references
    elem.clear()
    while elem.getprevious() is not None:
        del elem.getparent()[0]
        
    teststring = ', '.join(testlist) 
    # print(teststring)
        
    if any(lcsh in teststring for lcsh in termlist):
        #print('yes')
        
        # if that is true, we want the metadata
        # so let's make a dict to hold it
        # this dict will be reset with every file loop
        filedict = {}
        
        for xmltag in taglist:
            # make an empty list to hold what is in each tag, 
            # which will be written to our dict in a few steps
            elementlist = []
            
            context = etree.iterparse(file, events=('end',), tag=xmltag)
            for event, elem in context:
                elementlist.append(elem.text)
            
            # the below should make things faster - I think? 
            # reclaim the memory at the end of each loop -
            # clears unneeded node references
            elem.clear()
            while elem.getprevious() is not None:
                del elem.getparent()[0]
            # assign to the dictionary
            filedict[xmltag] = ', '.join(elementlist)
            
        # after it has looped through all the xmltags, 
        # add the filedict to list of dicts 
        listofdicts.append(filedict)
    #else:
        #print('no')
# Out:
# 2.78 s ± 334 ms per loop (mean ± std. dev. of 10 runs, 1 loop each)

# %%
listofdicts
# Out:
# []

# %%
dictsdf = pd.DataFrame(listofdicts)

# %%
dictsdf
# Out:
#     ESTCID currentVolume                                       displayTitle  \
# 0  T110070             0  The travels of the learned Father Montfaucon f...
#
#    documentID                                          fullTitle imprintCity  \
# 0  0084800600  The travels of the learned Father Montfaucon f...      London
#
#                                          imprintFull  \
# 0  London : printed by D. L. for E. Curll at the ...
#
#                                     imprintPublisher language  \
# 0  printed by D. L. for E. Curll at the Dial and ...  English
#
#                                           locSubject                 module  \
# 0  Italy, Description and travel, Early works to ...  History and Geography
#
#                                                notes   pubDate  \
# 0  With an index.  In this issue the imprint date...  17120101
#
#   publicationPlace totalVolumes
# 0           London            0

# %% [markdown]
# ## Applying it to all the files
#
# Now that I have this code working, I should be able to apply it to all the other files.
#
# I've asked an astute colleague (thanks Jonathan!) to look over the above, in case there is some error that would cause something to cascade and run forever (or, just run really slow). That's most likely to happen because of my unfamiliarity with lxml. Pandas, I think, should be able to handle what I'm asking of it.
#
# So now, step one of this new task: get a file list.
#
# We'll start with the HistAndGeo section of ECCOII, since it has only 3385 files as opposed to the ~14000 files of ECCOI (ECCO was released in two segments). I'm also fairly hopeful that there should be at least one or two pieces of travel writing in there, since it is the ECCO genre most closely related to travel writing.

# %%
filelist = glob.glob('D:/ECCOII 2001/HistAndGeo/XML/*.xml')

# %%
len(filelist)
# Out:
# 3384

# %%
shortfilelist = filelist[:100]
shortfilelist[:5]
# Out:
# ['D:/ECCOII 2001/HistAndGeo/XML\\1299100101.xml',
#  'D:/ECCOII 2001/HistAndGeo/XML\\1299100102.xml',
#  'D:/ECCOII 2001/HistAndGeo/XML\\1299100103.xml',
#  'D:/ECCOII 2001/HistAndGeo/XML\\1299100200.xml',
#  'D:/ECCOII 2001/HistAndGeo/XML\\1299100301.xml']

# %% [markdown]
# Okay, now I need to replicate the code up above so that it will work on this larger batch.
#
# I'm thinking, as well, of things that I will have to watch for: where will these files overlap with the ones in mybib already? I will have to be careful when integrating and comparing my various points of data, but the volume information and the file id numbering system (ie, having 0s vs 1/2/etc on the end of the filename) should help!

# %% [markdown]
# So, let's modify the code that I used earlier.
#
# In particular, I want to add a line that will note which ECCO segment it came from - ECCOI or ECCOII.

# %%
# this list of dicts will hold all a dict that holds
# the metadata for each relevant file
listofdicts = []

for file in shortfilelist:
    
    # the first iterparse will test to see if it has the desired lcsh.
    testparse = etree.iterparse(file, events=('end',), tag = 'locSubject')
    testlist = []
    for event, elem in testparse:
        testlist.append(elem.text)
        
    # the below will reclaim the memory at the end of each loop -
    # clears unneeded node references
    elem.clear()
    while elem.getprevious() is not None:
        del elem.getparent()[0]
        
    # and back to the purpose of our code - 
    # note that putting it in a string makes it easier to search
    # comparing list items required an exact match,
    # and I wanted fuzzier searching, 
    # just in case there were any errors in the controlled vocabulary
    # of the lcsh.
    teststring = ', '.join(testlist)     
    if any(lcsh in teststring for lcsh in termlist):
        
        # if that is true, we want the metadata for that file
        # so let's make a dict to hold it
        # this dict will be reset with every file loop
        filedict = {}
        
        # a dict entry to indicate which ECCO release it came from
        filedict['eccorelease'] = '2'
        
        for xmltag in taglist:
            # make an empty list to hold what is in each tag, 
            # which will be written to our dict in a few steps
            elementlist = []
            
            context = etree.iterparse(file, events=('end',), tag=xmltag)
            for event, elem in context:
                elementlist.append(elem.text)
            
            # the below should make things faster - I think? 
            # reclaim the memory at the end of each loop -
            # clears unneeded node references
            elem.clear()
            while elem.getprevious() is not None:
                del elem.getparent()[0]
            # assign to the dictionary
            filedict[xmltag] = ', '.join(elementlist)
            
        # after it has looped through all the xmltags, 
        # add the filedict to list of dicts 
        listofdicts.append(filedict)

# %%
dictsdf = pd.DataFrame(listofdicts)

# %%
dictsdf
# Out:
#     ESTCID currentVolume                                       displayTitle  \
# 0  N025387     Volume 16  The World displayed; Or, A curious collection ...
# 1  N031356             0  An essay towards a description of the city of ...
# 2  N029227             0  Interesting account of the early voyages, made...
# 3  N031489      Volume 1  An entertaining journey to the Netherlands; co...
# 4  N031489      Volume 2  An entertaining journey to the Netherlands; co...
# 5  N031489      Volume 3  An entertaining journey to the Netherlands; co...
# 6  T188570             0  A New collection of voyages and travels, dedic...
# 7  T172346             0  Miscellaneous remarks made on the spot, in a l...
#
#    documentID                                          fullTitle imprintCity  \
# 0  1309700116  The World displayed; Or, A curious collection ...      London
# 1  1309700600  An essay towards a description of the city of ...      [Bath]
# 2  1309900200  Interesting account of the early voyages, made...      London
# 3  1309900301  An entertaining journey to the Netherlands; co...      London
# 4  1309900302  An entertaining journey to the Netherlands; co...      London
# 5  1309900303  An entertaining journey to the Netherlands; co...      London
# 6  1309901100  A New collection of voyages and travels, dedic...      London
# 7  1310300400  Miscellaneous remarks made on the spot, in a l...      London
#
#                                          imprintFull  \
# 0  London : Printed for J. Newbery, at the Bible ...
# 1  [Bath] : Printed for W. Frederick, bookseller,...
# 2  London : Printed for the proprietors, and sold...
# 3  London : printed for W. Smith, M DCC LXXXII. [...
# 4  London : printed for W. Smith, M DCC LXXXII. [...
# 5  London : printed for W. Smith, M DCC LXXXII. [...
# 6  London : Printed for E. Newbery, the corner of...
# 7  London : Printed for S. Hooper, at Gay's Head,...
#
#                                     imprintPublisher language  \
# 0  Printed for J. Newbery, at the Bible and Sun, ...  English
# 1      Printed for W. Frederick, bookseller, in Bath  English
# 2  Printed for the proprietors, and sold at Stalk...  English
# 3                               printed for W. Smith  English
# 4                               printed for W. Smith  English
# 5                               printed for W. Smith  English
# 6  Printed for E. Newbery, the corner of St. Paul...  English
# 7  Printed for S. Hooper, at Gay's Head, near Bea...  English
#
#                                           locSubject                 module  \
# 0                                Voyages and travels  History and Geography
# 1  Bath (England), Description and travel, Early ...  History and Geography
# 2  Explorers, Portugal, Early works to 1800, Expl...  History and Geography
# 3  Netherlands, Description and travel, Early wor...  History and Geography
# 4  Netherlands, Description and travel, Early wor...  History and Geography
# 5  Netherlands, Description and travel, Early wor...  History and Geography
# 6           Voyages and travels, Early works to 1800  History and Geography
# 7  Italy, Description and travel, Early works to ...  History and Geography
#
#                                                notes   pubDate  \
# 0                                                     17670101
# 1  With an additional titlepage for pt. 1: 'An es...  17420101
# 2                                                     17900101
# 3                  Coriat Junior = Samuel Paterson?.  17820101
# 4                  Coriat Junior = Samuel Paterson?.  17820101
# 5                  Coriat Junior = Samuel Paterson?.  17820101
# 6  William Mavor is the editor of the 'Historical...  17960101
# 7                                                     17560101
#
#   publicationPlace totalVolumes
# 0           London            1
# 1             Bath            0
# 2           London            0
# 3           London            3
# 4           London            3
# 5           London            3
# 6           London            0
# 7           London            0

# %% [markdown]
# Hurrah, it worked! Now, to replicate the code and do it for the multiple sections of ECCO II.

# %% [markdown]
# # ECCO Part 2
# Let's run our analysis on ECCO pt 2 (there are less files here than on ECCO pt 1!)

# %%
from lxml import etree
import pandas as pd
import glob

# %% [markdown]
# Because many of the files are

# %%
import os
filelist = []
for root, dirs, files in os.walk(mypath):
    for file in files:
        if file.endswith(".xml"):
             filelist.append(os.path.join(root, file))

# %%
len(filelist)
# Out:
# 52690

# %%
filelist[:10]
# Out:
# ['D:/ECCOII 2001/GenRef\\XML\\1336600100.xml',
#  'D:/ECCOII 2001/GenRef\\XML\\1336600200.xml',
#  'D:/ECCOII 2001/GenRef\\XML\\1336600300.xml',
#  'D:/ECCOII 2001/GenRef\\XML\\1336600400.xml',
#  'D:/ECCOII 2001/GenRef\\XML\\1336600500.xml',
#  'D:/ECCOII 2001/GenRef\\XML\\1336600600.xml',
#  'D:/ECCOII 2001/GenRef\\XML\\1336600700.xml',
#  'D:/ECCOII 2001/GenRef\\XML\\1336600800.xml',
#  'D:/ECCOII 2001/GenRef\\XML\\1336600900.xml',
#  'D:/ECCOII 2001/GenRef\\XML\\1336601000.xml']

# %% [markdown]
# Looks good - there shouldn't be any subfolders or word docs, for example.
#
# I am...a little hesitant to run something on such a large number of files. What if it breaks, partway through? What if my laptop panics? I think, however, this is a good opportunity to take a break, make some hot chocolate, watch the snow fall, and let my code run (and then, maybe, return to writing?!)

# %% [markdown]
# ### UH OH.
#
# *revised plan* Okay, so I started it running, and then let it be. And, of course, something didn't work and it threw a "file not found" error. :( The weird thing, is that is didn't happen on the `testparse = etree` line like I would have expected; instead, it happend on the first `for event, elem in testparse: testlist.append(elem.text)`.
#
# So, I'm going to return to doing it in batches; at least, then, I will know whether it is happening in a certain folder. Grumble grumble.
#
# (side note: I am a little concerned about what if the capitalization happens to be different somewhere? But, I think I can just run a `locsubject` (without the capital S) to catch any differences...)
#
# In order to do a longer test, I'll use the `ECCOII HistAndGeo` subsection as an experiment - there were about 3300 files in there.
#
# _side note_: My laptop went to sleep just after the 2500 mark, so I had to start it back up again, woops. No duplicates in the total of `312` relevant files below, though I will have to filter out anything that isn't printed in Great Britain - there are some texts printed in New York, Dublin, etc., in there.

# %%
filelistHistAndGeo = glob.glob('D:/ECCOII 2001/HistAndGeo/XML/*.xml')

# %%
termlist = ['travel', 'discov', 'explor', 'voyage', 'guide', 'antiquit']
taglist = ['documentID', 'ESTCID', 'pubDate','ESTCID',
           'language','module','locSubject','notes',
           'fullTitle','displayTitle','currentVolume', 
           'totalVolumes', 'imprintPublisher','imprintFull',
           'imprintCity', 'publicationPlace']

# this list of dicts will hold all a dict that holds
# the metadata for each relevant file

# listofdicts = []

# and, a count so that I can track my progress
count = 2500

for file in filelistHistAndGeo[2500:]:
    count+=1
    if (count % 500) == 0:
        print(count)
    
    
    # the first iterparse will test to see if it has the desired lcsh.
    testparse = etree.iterparse(file, events=('end',), tag = 'locSubject')
    testlist = []
    for event, elem in testparse:
        testlist.append(elem.text)
        
    # the below will reclaim the memory at the end of each loop -
    # clears unneeded node references
    elem.clear()
    while elem.getprevious() is not None:
        del elem.getparent()[0]
        
    # and back to the purpose of our code - 
    # note that putting it in a string makes it easier to search
    # comparing list items required an exact match,
    # and I wanted fuzzier searching, 
    # just in case there were any errors in the controlled vocabulary
    # of the lcsh.
    teststring = ', '.join(testlist)     
    if any(lcsh in teststring for lcsh in termlist):
        
        # if that is true, we want the metadata for that file
        # so let's make a dict to hold it
        # this dict will be reset with every file loop
        filedict = {}
        
        # a dict entry to indicate which ECCO release it came from
        filedict['eccorelease'] = '2'
        
        for xmltag in taglist:
            # make an empty list to hold what is in each tag, 
            # which will be written to our dict in a few steps
            elementlist = []
            
            context = etree.iterparse(file, events=('end',), tag=xmltag)
            for event, elem in context:
                elementlist.append(elem.text)
            
            # the below should make things faster - I think? 
            # reclaim the memory at the end of each loop -
            # clears unneeded node references
            elem.clear()
            while elem.getprevious() is not None:
                del elem.getparent()[0]
            # assign to the dictionary
            filedict[xmltag] = ', '.join(elementlist)
            
        # after it has looped through all the xmltags, 
        # add the filedict to list of dicts 
        listofdicts.append(filedict)
# Out:
# 3000

# %%
len(listofdicts)
# Out:
# 312

# %%
dfHistAndGeo = pd.DataFrame(listofdicts)
dfHistAndGeo
# Out:
#       ESTCID currentVolume                                       displayTitle  \
# 0    N025387     Volume 16  The World displayed; Or, A curious collection ...
# 1    N031356             0  An essay towards a description of the city of ...
# 2    N029227             0  Interesting account of the early voyages, made...
# 3    N031489      Volume 1  An entertaining journey to the Netherlands; co...
# 306  T097845      Volume 1  A Collection of voyages and travels, some now ...
# 307  T097845      Volume 2  A Collection of voyages and travels, some now ...
# 308  T097845      Volume 3  A Collection of voyages and travels, some now ...
# 309  T097845      Volume 4  A Collection of voyages and travels, some now ...
# 310  T097845      Volume 5  A Collection of voyages and travels, some now ...
# 311  T097845      Volume 6  A Collection of voyages and travels, some now ...
#
#      documentID eccorelease  \
# 0    1309700116           2
# 1    1309700600           2
# 2    1309900200           2
# 3    1309900301           2
# 4    1309900302           2
# 5    1309900303           2
# 6    1309901100           2
# 7    1310300400           2
# 8    1313200301           2
# 9    1313200302           2
# 10   1313200400           2
# 11   1316200401           2
# 12   1316200402           2
# 13   1316400600           2
# 14   1321200900           2
# 15   1324400100           2
# 16   1324400900           2
# 17   1331000300           2
# 18   1331201100           2
# 19   1331400300           2
# 20   1334900101           2
# 21   1334900102           2
# 22   1334900103           2
# 23   1334900104           2
# 24   1334900105           2
# 25   1334900106           2
# 26   1334900107           2
# 27   1334900108           2
# 28   1334900109           2
# 29   1335000110           2
# ..          ...         ...
# 282  1696000600           2
# 283  1696001000           2
# 284  1696400300           2
# 285  1698000201           2
# 286  1698000202           2
# 287  1698200100           2
# 288  1698200400           2
# 289  1698500500           2
# 290  1705600300           2
# 291  1726100301           2
# 292  1726200102           2
# 293  1726200103           2
# 294  1726700501           2
# 295  1726800102           2
# 296  1726800201           2
# 297  1726800400           2
# 298  1726900100           2
# 299  1727800301           2
# 300  1727800302           2
# 301  1728000101           2
# 302  1728000102           2
# 303  1728000103           2
# 304  1728900101           2
# 305  1728900102           2
# 306  1736200201           2
# 307  1736200202           2
# 308  1736300103           2
# 309  1736300104           2
# 310  1736400105           2
# 311  1736400106           2
#
#                                              fullTitle   imprintCity  \
# 0    The World displayed; Or, A curious collection ...        London
# 1    An essay towards a description of the city of ...        [Bath]
# 2    Interesting account of the early voyages, made...        London
# 3    An entertaining journey to the Netherlands; co...        London
# 4    An entertaining journey to the Netherlands; co...        London
# 5    An entertaining journey to the Netherlands; co...        London
# 6    A New collection of voyages and travels, dedic...        London
# 7    Miscellaneous remarks made on the spot, in a l...        London
# 8    The memoirs of Charles-Lewis, Baron de Pollnit...        London
# 9    The memoirs of Charles-Lewis, Baron de Pollnit...        London
# 10   A history of a voyage to the coast of Africa, ...  Philadelphia
# 11   Modern voyages: Containing a variety of useful...        Dublin
# 12   Modern voyages: Containing a variety of useful...        Dublin
# 13   The foreign travels and dangerous voyages of t...        London
# 14   An accountof the shipwreck and captivity of Mr...        London
# 15   Owen's new book of fairs, published by the Kin...        London
# 16   Morse's Geography. This day is published, in o...        London
# 17   The Present state of Sicily and Malta, Extract...        London
# 18   Holland: a jaunt to the principal places in th...        London
# 19        A Description of the hermitage of Warkworth.    [London? ]
# 20   The world displayed; or, A curious collection ...        Dublin
# 21   The world displayed; or, A curious collection ...        Dublin
# 22   The world displayed; or, A curious collection ...        Dublin
# 23   The world displayed; or, A curious collection ...        Dublin
# 24   The world displayed; or, A curious collection ...        Dublin
# 25   The world displayed; or, A curious collection ...        Dublin
# 26   The world displayed; or, A curious collection ...        Dublin
# 27   The world displayed; or, A curious collection ...        Dublin
# 28   The world displayed; or, A curious collection ...        Dublin
# 29   The world displayed; or, A curious collection ...        Dublin
# ..                                                 ...           ...
# 282  A new and enlarged book of sailing directions ...        London
# 283  The admirable travels of Thomas Jenkins. And D...        London
# 284  East-Bourn, being an descriptive account of th...        London
# 285  A journey made in the summer of 1794, through ...        London
# 286  A journey made in the summer of 1794, through ...        London
# 287  The world in miniature; or, The entertaining t...        Dublin
# 288  A tour through Ireland. In several entertainin...        Dublin
# 289  An authentic narrative of some remarkable and ...        Dublin
# 290  The voiage and travaile of Sir John Maundevile...        London
# 291  Travels in Switzerland, and in the country of ...        London
# 292  Travels in Switzerland, and in the country of ...        London
# 293  Travels in Switzerland, and in the country of ...        London
# 294  An account of the European settlements in Amer...        London
# 295  An account of the European settlements in Amer...        London
# 296  Travels through Syria and Egypt, in the years ...        London
# 297  Observations on the western parts of England, ...        London
# 298  Travels in several parts of Turkey, Egypt, and...        London
# 299  A year's journey through France, and part of S...          Bath
# 300  A year's journey through France, and part of S...          Bath
# 301  Letters from Italy, describing the manners, cu...        Dublin
# 302  Letters from Italy, describing the manners, cu...        Dublin
# 303  Letters from Italy, describing the manners, cu...        Dublin
# 304  Travels from St. Petersburg in Russia, to dive...       Glasgow
# 305  Travels from St. Petersburg in Russia, to dive...       Glasgow
# 306  A Collection of voyages and travels, some now ...        London
# 307  A Collection of voyages and travels, some now ...        London
# 308  A Collection of voyages and travels, some now ...        London
# 309  A Collection of voyages and travels, some now ...        London
# 310  A Collection of voyages and travels, some now ...        London
# 311  A Collection of voyages and travels, some now ...        London
#
#                                            imprintFull  \
# 0    London : Printed for J. Newbery, at the Bible ...
# 1    [Bath] : Printed for W. Frederick, bookseller,...
# 2    London : Printed for the proprietors, and sold...
# 3    London : printed for W. Smith, M DCC LXXXII. [...
# 4    London : printed for W. Smith, M DCC LXXXII. [...
# 5    London : printed for W. Smith, M DCC LXXXII. [...
# 6    London : Printed for E. Newbery, the corner of...
# 7    London : Printed for S. Hooper, at Gay's Head,...
# 8    London : Printed for Daniel Browne, at the Bla...
# 9    London : Printed for Daniel Browne, at the Bla...
# 10   Philadelphia : printed for the author, by S. C...
# 11   Dublin : printed for Chamberlaine and Rice, P....
# 12   Dublin : printed for Chamberlaine and Rice, P....
# 13             London : printed for M. Hotham, [1710?]
# 14   London : Printed for C. Forster, in the Poultr...
# 15   London : Printed (by assignment from W. Owen) ...
# 16   London : Printed for John Stockdale, Piccadill...
# 17   London : Printed for G. Kearsley, at Johnson's...
# 18   London : Printed, and sold by W.Hay, next to t...
# 19                             [London? : s.n., 1800?]
# 20   Dublin : printed by James Williams, M,DCC,LXXI...
# 21   Dublin : printed by James Williams, M,DCC,LXXI...
# 22   Dublin : printed by James Williams, M,DCC,LXXI...
# 23   Dublin : printed by James Williams, M,DCC,LXXI...
# 24   Dublin : printed by James Williams, M,DCC,LXXI...
# 23                                 Voyages and travels  History and Geography
# 24                                 Voyages and travels  History and Geography
# 25                                 Voyages and travels  History and Geography
# 26                                 Voyages and travels  History and Geography
# 27                                 Voyages and travels  History and Geography
# 28                                 Voyages and travels  History and Geography
# 29                                 Voyages and travels  History and Geography
# ..                                                 ...                    ...
# 282                  Pilot guides, Florida, Straits of  History and Geography
# 283  Voyages and travels, England, London, Early wo...  History and Geography
# 284  Sussex (England), Description and travel, Earl...  History and Geography
# 285                     Europe, Description and travel  History and Geography
# 286                     Europe, Description and travel  History and Geography
# 287           Voyages and travels, Early works to 1800  History and Geography
# 288                    Ireland, Description and travel  History and Geography
# 289           Voyages and travels, Personal narratives  History and Geography
# 290                                Voyages and travels  History and Geography
# 291                Switzerland, Description and travel  History and Geography
# 292                Switzerland, Description and travel  History and Geography
# 293                Switzerland, Description and travel  History and Geography
# 294  United States, Description and travel, Early w...  History and Geography
# 295  United States, Description and travel, Early w...  History and Geography
# 296  Syria, Description and travel, Early works to ...  History and Geography
# 297  England, Description and travel, Early works t...  History and Geography
# 298                Middle East, Description and travel  History and Geography
# 299  France, Description and travel, Early works to...  History and Geography
# 300  France, Description and travel, Early works to...  History and Geography
# 301                      Italy, Description and travel  History and Geography
# 302                      Italy, Description and travel  History and Geography
# 303                      Italy, Description and travel  History and Geography
# 304                       Asia, Description and travel  History and Geography
# 305                       Asia, Description and travel  History and Geography
# 306                                Voyages and travels  History and Geography
# 307                                Voyages and travels  History and Geography
# 308                                Voyages and travels  History and Geography
# 309                                Voyages and travels  History and Geography
# 310                                Voyages and travels  History and Geography
# 311                                Voyages and travels  History and Geography
#
#                                                  notes   pubDate  \
# 0                                                       17670101
# 1    With an additional titlepage for pt. 1: 'An es...  17420101
# 2                                                       17900101
# 3                    Coriat Junior = Samuel Paterson?.  17820101
# 4                    Coriat Junior = Samuel Paterson?.  17820101
# 5                    Coriat Junior = Samuel Paterson?.  17820101
# 6    William Mavor is the editor of the 'Historical...  17960101
# 7                                                       17560101
# 8    Translated by Stephen Whatley.  In this editio...  17390101
# 9    Translated by Stephen Whatley.  In this editio...  17390101
# 10   "The author relating the history of his travel...  17970101
# 11   The imprint in vol. 2 is enlarged by the addit...  17900101
# 12   The imprint in vol. 2 is enlarged by the addit...  17900101
# 13                                                      17100101
# 14   Price in square brackets: (Price Two Shillings...  17890101
# 15   With an initial copyright leaf.  Also publishe...  17990101
# 16   Advertisement for new books printed for John S...  17920101
# 17   With a final errata leaf.  P. iv misnumbered v...  17880101
# 18                    Price on title page: (Price 2s.)  17750101
# 19                                                      18000101
# 20   Compiled by Christopher Smart, Oliver Goldsmit...  17790101
# 21   Compiled by Christopher Smart, Oliver Goldsmit...  17790101
# 22   Compiled by Christopher Smart, Oliver Goldsmit...  17790101
# 23   Compiled by Christopher Smart, Oliver Goldsmit...  17790101
# 24   Compiled by Christopher Smart, Oliver Goldsmit...  17790101
# 25   Compiled by Christopher Smart, Oliver Goldsmit...  17790101
# 26   Compiled by Christopher Smart, Oliver Goldsmit...  17790101
# 27   Compiled by Christopher Smart, Oliver Goldsmit...  17790101
# 28   Compiled by Christopher Smart, Oliver Goldsmit...  17790101
# 29   Compiled by Christopher Smart, Oliver Goldsmit...  17790101
# ..                                                 ...       ...
# 282  At foot of titlepage: "N.B. These directions a...  17960101
# 283  Written in the first person by David Lowellin....  17910101
# 284                                                     17990101
# 285                                                     17960101
# 286                                                     17960101
# 287                                     With an index.  17510101
# 288  Anonymous. By William Rufus Chetwood.  A reiss...  17480101
# 289  Written by Newton himself.  First published as...  17960101
# 290  Titlepage in red and black, preceding a black ...  17270101
# 291                                                     17910101
# 292                                                     17910101
# 293                                                     17910101
# 294  Anonymous. Probably a collaboration by William...  17700101
# 295  Anonymous. Probably a collaboration by William...  17700101
# 296  Largely a reimpression of the 1787 London edit...  17880101
# 297  The same setting of type was also printed with...  17980101
# 298                            Horizontal chain lines.  17740101
# 299                        With a list of subscribers.  17770101
# 300                        With a list of subscribers.  17770101
# 301  An English woman = Anna, wife of Sir John Rigg...  17760101
# 302  An English woman = Anna, wife of Sir John Rigg...  17760101
# 303  An English woman = Anna, wife of Sir John Rigg...  17760101
# 304  With a list of subscribers in vol.1.  "Volume ...  17630101
# 305  With a list of subscribers in vol.1.  "Volume ...  17630101
# 306  Compiled by Awnsham Churchill and John Churchi...  17440101
# 307  Compiled by Awnsham Churchill and John Churchi...  17440101
# 308  Compiled by Awnsham Churchill and John Churchi...  17440101
# 309  Compiled by Awnsham Churchill and John Churchi...  17440101
# 310  Compiled by Awnsham Churchill and John Churchi...  17440101
# 311  Compiled by Awnsham Churchill and John Churchi...  17440101
#
#     publicationPlace totalVolumes
# 0             London            1
# 1               Bath            0
# 2             London            0
# 3             London            3
# 4             London            3
# 5             London            3
# 6             London            0
# 7             London            0
# 8             London            2
# 9             London            2
# 10      Philadelphia            0
# 11            Dublin            2
# 12            Dublin            2
# 13            London            0
# 14            London            0
# 15            London            0
# 16            London            0
# 17            London            0
# 18            London            0
# 19            London            0
# 20            Dublin           20
# 21            Dublin           20
# 22            Dublin           20
# 23            Dublin           20
# 24            Dublin           20
# 25            Dublin           20
# 26            Dublin           20
# 27            Dublin           20
# 28            Dublin           20
# 29            Dublin           20
# ..               ...          ...
# 282           London            0
# 283           London            0
# 284           London            0
# 285           London            2
# 286           London            2
# 287           Dublin            0
# 288           Dublin            0
# 289           Dublin            0
# 290           London            0
# 291           London            3
# 292           London            3
# 293           London            3
# 294           London            2
# 295           London            2
# 296           London            2
# 297           London            0
# 298           London            0
# 299             Bath            2
# 300             Bath            2
# 301           London            3
# 302           London            3
# 303           London            3
# 304          Glasgow            2
# 305          Glasgow            2
# 306           London            6
# 307           London            6
# 308           London            6
# 309           London            6
# 310           London            6
# 311           London            6
#
# [312 rows x 16 columns]

# %%
dfHistAndGeo.to_csv('files/HistAndGeo.csv')

# %% [markdown]
# Okay, so, it worked (hurrah!) but it did take quite a while - a few hours. At this rate, I might have to leave do multiple sections in order to gather them all, unless there is a faster method (which there almost undoubtedly is).
